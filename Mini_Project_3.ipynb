# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedant817/Python-Assignements/blob/main/Mini_Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
# Data to be computered as given in the question file.

# %%
File_Size=[200,400,600,800,1000]
C=[12,20,34,45,55]
Cpp=[15,25,36,50,60]
Java=[18,30,40,55,70]
Perl=[20,35,45,60,80]
Python=[25,40,53,75,100]

# %%
plot1=sns.lineplot(x=File_Size,y=C,label="C")
plot2=sns.lineplot(x=File_Size,y=Cpp,label="C++")
plot3=sns.lineplot(x=File_Size,y=Java,label="Java")
plot4=sns.lineplot(x=File_Size,y=Perl,label="Perl")
plot5=sns.lineplot(x=File_Size,y=Python,label="Python")
plot1.set_xlabel("File Size")
plot1.set_ylabel("Time Taken")
# Out:
# Text(0, 0.5, 'Time Taken')
